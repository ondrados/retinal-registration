# %%
import cv2
import os
import glob
import numpy as np
import random
import torch
import torchvision
from PIL import Image
from matplotlib import pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# %%
dataset_path = "/Users/ondra/dev/personal/siamese-registration/data/frame_sequences"

# %%
class MyDataset(Dataset):
    def __init__(self, transforms=None, path=dataset_path):
        self.path = path

        self.transforms = transforms

        self.folder_paths = glob.glob(os.path.join(self.path, '*'))
        self.id_list = []
        self.image_list = []

        for folder in self.folder_paths:
            images = glob.glob(folder + '/*jpg')
            self.id_list.append(os.path.basename(folder))
            self.image_list.extend(images)

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, index):
        image = cv2.imread(self.image_list[index])
        rows, cols, ch = image.shape
        
        angle = random.randint(-5, 5)
        center = (image.shape[1]//2, image.shape[0]//2)
        scale = 1
        
        M = cv2.getRotationMatrix2D( center, angle, scale)
        
        dst = cv2.warpAffine(image, M, (cols, rows))
        
        h = 1500
        w = 2250
        
        image = image[image.shape[0]//2-h//2:image.shape[0]//2+h//2,
                         image.shape[1]//2-w//2:image.shape[1]//2+w//2]
        image2 = dst[dst.shape[0]//2-h//2:dst.shape[0]//2+h//2,
                       dst.shape[1]//2-w//2:dst.shape[1]//2+w//2]
        
        if self.transforms:
            image = self.transforms(image)
            image2 = self.transforms(image2)

        return image, image2, M

# %%
dataset = MyDataset(path=dataset_path, transforms=transforms.Compose([transforms.ToTensor(),]))

# %%
dataset_iter = iter(dataset)

# %%
image1, image2, M = next(dataset_iter)
grid = torchvision.utils.make_grid([image1, image2])
plt.figure(figsize=(16, 9))
plt.imshow(grid.numpy().transpose(1, 2, 0))

# %%
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
from torchvision import models

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        self.cnn1 = models.resnet50(pretrained=False)
        self.fc1 = nn.Linear(2*1000, 500)
        self.fc2 = nn.Linear(500, 500)
        self.fc3 = nn.Linear(500, 6)


    def forward(self, input1, input2):
        cnn_out1 = self.cnn1(input1)
        cnn_out2 = self.cnn1(input2)
        
        concat = torch.cat((cnn_out1, cnn_out2), 1)
        
        fc1_out = self.fc1(concat)
        fc1_relu_out = F.relu(fc1_out)
        
        fc2_out = self.fc2(fc1_relu_out)
        fc2_relu_out = F.relu(fc2_out)
        
        output = self.fc3(fc2_relu_out)
        
        return output

# %%
dataset = MyDataset(path=dataset_path, transforms=transforms.Compose([transforms.ToTensor(),]))
trainloader = DataLoader(dataset, batch_size=1, shuffle=False)
it = iter(trainloader)

# %%
image1, image2, M = next(it)

# %%
net = SiameseNetwork()

# %%
out = net(image1, image2)

# %%
print(out)
print(torch.reshape(out, (1, 2, 3)))
print(M)
# Out:
# tensor([[ 0.0356, -0.0001, -0.1293,  0.0156, -0.0718, -0.0720]],
#        grad_fn=<AddmmBackward0>)
# tensor([[[ 0.0356, -0.0001, -0.1293],
#          [ 0.0156, -0.0718, -0.0720]]], grad_fn=<ReshapeAliasBackward0>)
# tensor([[[  0.9848,  -0.1736,  74.4507],
#          [  0.1736,   0.9848, -80.9751]]], dtype=torch.float64)

# %%
net = SiameseNetwork()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=0.001)
#optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

dataset = MyDataset(path=dataset_path, transforms=transforms.Compose([transforms.ToTensor(),]))
trainloader = DataLoader(dataset, batch_size=1, shuffle=False)

running_loss = 0.0
training_loss = []

for epoch in range(0, 10):
    for i, data in enumerate(trainloader):
        img0, img1 , labels = data
        optimizer.zero_grad()
        outputs = net(img0, img1)
        loss = criterion(torch.reshape(outputs, (1, 2, 3)),labels)
        loss_item = loss.item()
        running_loss += loss_item
        loss.backward()
        optimizer.step()
        print(f"Epoch: {epoch}, iteration: {i} of {len(trainloader)}, loss: {loss_item}")
    
    training_loss.append(running_loss / len(trainloader))
# Out:
# Epoch: 0, iteration: 0 of 252, loss: -0.5945566826500358
# Epoch: 0, iteration: 1 of 252, loss: 3.4708432478934115
# Epoch: 0, iteration: 2 of 252, loss: 7.231082393986083
# Epoch: 0, iteration: 3 of 252, loss: 1.0607746304665318
# Epoch: 0, iteration: 4 of 252, loss: 0.30114131220873946
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/qz/tnst848s0vz2c7b4sf96rql40000gn/T/ipykernel_43703/2755489603.py in <module>
#      14         img0, img1 , labels = data
#      15         optimizer.zero_grad()
# ---> 16         outputs = net(img0, img1)
#      17         loss = criterion(torch.reshape(outputs, (1, 2, 3)),labels)
#      18         loss_item = loss.item()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /var/folders/qz/tnst848s0vz2c7b4sf96rql40000gn/T/ipykernel_43703/1865462194.py in forward(self, input1, input2)
#       9
#      10     def forward(self, input1, input2):
# ---> 11         cnn_out1 = self.cnn1(input1)
#      12         #cnn_out1 = cnn_out1.view(cnn_out1.size()[0], -1)
#      13         cnn_out2 = self.cnn1(input2)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torchvision/models/resnet.py in forward(self, x)
#     247
#     248     def forward(self, x: Tensor) -> Tensor:
# --> 249         return self._forward_impl(x)
#     250
#     251
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torchvision/models/resnet.py in _forward_impl(self, x)
#     237         x = self.layer1(x)
#     238         x = self.layer2(x)
# --> 239         x = self.layer3(x)
#     240         x = self.layer4(x)
#     241
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torchvision/models/resnet.py in forward(self, x)
#     122         identity = x
#     123
# --> 124         out = self.conv1(x)
#     125         out = self.bn1(out)
#     126         out = self.relu(out)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     444
#     445     def forward(self, input: Tensor) -> Tensor:
# --> 446         return self._conv_forward(input, self.weight, self.bias)
#     447
#     448 class Conv3d(_ConvNd):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     440                             weight, bias, self.stride,
#     441                             _pair(0), self.dilation, self.groups)
# --> 442         return F.conv2d(input, weight, bias, self.stride,
#     443                         self.padding, self.dilation, self.groups)
#     444
#
# KeyboardInterrupt:

# %%
random.randint(-5, 5)
# Out:
# 4
