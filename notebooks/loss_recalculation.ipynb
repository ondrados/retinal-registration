# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
training_loss_arr = np.array([2.5, 3.75, 5.75, 6.75])
validation_loss_arr = np.array([1.5, 2.35, 4.87, 5.21])
len_train_loader = 4
len_test_loader = 3

# %%
tmp = training_loss_arr * len_train_loader
running_loss_final = np.insert(tmp[1:] - tmp[:-1], 0, tmp[0])
training_loss_final = running_loss_final / len_train_loader

# %%
tmp = validation_loss_arr * len_test_loader
val_running_loss_final = np.insert(tmp[1:] - tmp[:-1], 0, tmp[0])
validation_loss_final = val_running_loss_final / len_test_loader

# %%
training_loss_final
# Out:
# array([2.5 , 1.25, 2.  , 1.  ])

# %%
validation_loss_final
# Out:
# array([1.5 , 0.85, 2.52, 0.34])

# %%
plt.figure()
plt.plot(training_loss, label="training loss")
plt.plot(validation_loss, label="validation loss")
plt.title("Training loss")
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(training_loss_final, label="training loss")
plt.plot(validation_loss_final, label="validation loss")
plt.title("Training loss")
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show()
